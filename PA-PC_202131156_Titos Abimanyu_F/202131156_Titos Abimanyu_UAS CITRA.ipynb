# %% [markdown]
# # Titos Abimanyu 202131156

# %%
import cv2 
from rembg import remove
from PIL import Image
import matplotlib.pyplot as pyt
# Out:
# C:\Users\abima\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
def remove_background(input_image, result_image):
    input_image = Image.open(gambar_asli)

    pyt.subplot(1, 2, 1)
    pyt.imshow(input_image)
    pyt.title('Original Image')

    output_image = remove(input_image)

    pyt.subplot(1, 2, 2)
    pyt.imshow(output_image)
    pyt.title('Remove Background')

    output_image.save(gambar_hasil)
    
    pyt.tight_layout()
    pyt.show()

gambar_asli = 'buku.jpg'
gambar_hasil = 'buku_OUTPUT.png'
remove_background(gambar_asli, gambar_hasil)
